# %%
'''
Class means a blue print of object. It is a template or framework which is used to create an object.

system

front end
-html & class (streamlit,gradio)                                      # Fullstack, data science 
|
|
|
fastAPPI + React (Integrading (React), Backend framework (FastAPI))  # Fullstack, data science 
|
|
|
|
Backend 
-Files and folder structure with main.py                             # Fullstack, data science 
|

'''

# %%
'''
sqlite3 - no server data lite
cursor - to fetch the sql structure / data 
execute - to execute the create the table that we have cursor 
fetchone - to fetch the result but one entry
commit - save the changes and then execute
fetchall - it fetch all the entry

'''

# %%
import sqlite3

# %%
conn = sqlite3.connect('database.db')

# %%
cur = conn.cursor()

# %%
# Create a Entity table
cur.execute("CREATE TABLE movie(title, year, score)")

# %%
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchall()
# Out:
# [('movie',)]

# %%
cur.execute(""" insert into movie values ('abc','2025',20)""")

# %%
cur.execute(""" insert into movie values ('def','2026',40)""")

# %%
conn.commit()

# %%
a = cur.execute("select * from movie")
a.fetchall()
# Out:
# [('abc', '2025', 20), ('def', '2026', 40)]

# %%
''' 
Booking -- Transaction
|
user

- booking then database store 
35
- database will confirm / services in also option will there yes or no 
and if no the it will be another refund option

'''

# %%
'''
try:
  statements
  
excepts:
  statements
  
else:
  statements
  
finally:
  statements
'''

# %%
try:
    num1 = 100
    num2 = 0
    a = num1/num2
except ZeroDivisionError:
    print('Zero Division Error...Please checkyour calculation')
# Out:
# Zero Division Error...Please checkyour calculation

# %%
try:
    num1 = float(input('Enter number1 :'))
    num2 = float(input('Enter number2 :'))
    
except ValueError:
    print('Check the inputed values')
# Out:
# Check the inputed values

# %%
try:
    num1 = float(input('Enter number1 :'))
    num2 = float(input('Enter number2 :'))
    age = int(input('Enter the age :'))
except ValueError:
    print('Check the inputed values')

# %%
try:
    num1 = float(input('Enter number1 :'))
    num2 = float(input('Enter number2 :'))
    age = int(input('Enter the age :'))
    
    result = num1 +string1
    
except ValueError:
    print('Check the inputed values')
except TypeError:
    print('Check the calculation as you have added string + int')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       6     result = num1 +string1
#       7
#       8 except ValueError:
#       9     print('Check the inputed values')
# ---> 10 except TypeError:
#      11     print('Check the calculation as you have added string + int')
#
# NameError: name 'string1' is not defined

# %%
numbers = [10,20,30]

try:
    print(numbers[5])
except IndexError:
    print("index does not exist in the list")
# Out:
# index does not exist in the list

# %%
#Handling exception as object
try:
    result = 10 /0 
    
except ZeroDivisionError as e:
    print("Exception message:", e)
    print("Exception type:", type(e).__name__)
# Out:
# Exception message: division by zero
# Exception type: ZeroDivisionError

# %%
#try except else block:
num1 = 100
num2 = 20

try:
    result = num1 / num2
    
except ZeroDivisionError:
    print("Cannot divide by zero.")
    
else:
    print("Division successful,")
    print("Result:", result)
# Out:
# Division successful,
# Result: 5.0

# %%
class bank:
    def __init__(self,name,age,gender):
        try:
            self.name = name
            self.age = age
            self.gender = gender
        
        except ValueError:
            print('Check the inputed values')
        
        except TypeError:
            print('Check the calculation as you added string + int')
        
        finally:
            print('Zero Division Error...Please check your calculation')
        
        name = input('Enter your name : ')
        age = int(input('Enter your age : '))
        gender = input('Enter your gender : ')
        
        tjsb = bank(name,age,gender)

# %%
#Create Custom Loggings 
'''
to build railyway by logging 
give context 
i working as senior developer for india railway management , i want to design end to end application for indian railway reservation booking management 
system, the system design are as follow:1. streamlit as front end 2.python as framework with SQLite3 as database to store and retrive entries in real time basic.for 
every transaction or booking there will be loggs generated by system. the code structure must be design with orchestron modeling: prepare professonal prompt for me in order to design the whole system as an one application 


'''
import logging
logging.basicConfig(level = logging.INFO,
                    filename = 'railway.log',
                    filemode = 'w',
                    format = '%(asctime)s - %(levelname)s - %(message)s',
                    force = True)

# %%
logging.info('Check the ')

# %%
logging.info('Check the ')
